# %% [markdown]
# # Parsing the data
#
# - First, the `edf` files should be converted to `asc` with the `edf2asc` converter, which you can download from the SR Research forum.
# - Next, place the `asc` files in a folder called `data`, which is a subfolder of the folder where this notebook is located.
# - Then, run this script!
#
# The `get_data()` function below parses the data. Because you have structured the experiment as expected by `eyelinkparser`, this is very easy. Blinks are reconstructed in the pupil trace, and the data is downsampled by a factor of 10 to 100 Hz. This is done automatically by the `defaulttraceprocessor()`.
#
# We also perform baseline correction of the pupil trace, and reduce the length (depth) of the pupil trace to a sensible value that matches the length of the `presentation` phase during the experiment. Finally, we keep only a few columns (all other columsn are discarded), so that the data structure isn't too big.

# %%
from eyelinkparser import parse, defaulttraceprocessor
from datamatrix import operations as ops, series as srs, functional as fnc
from datamatrix import DataMatrix

@fnc.memoize(persistent=True) # Remove persistent to use in-memory caching.
def get_data():
    
    dm = parse(
        traceprocessor=defaulttraceprocessor(blinkreconstruct=False,downsample=10),        
    )
    
    dm.pupil = dm.ptrace_target
    dm.base = dm.ptrace_base 
    
    dm = ops.keep_only(dm,
        "pupil",
        "base",
        "subject_nr",
        "target_color",
        "Start_luminance",
        "path",
        "Gestalt",
        "start_color",
        "target",
        "position_target",
        "RSVP_Iteration",
        "progress_percentage",
        "response_time_new_keyboard_response",
        "stream",
        "Duration",
        "response",
        "practice",
        "count_trial_sequence"
                                          
    )

    return dm

# %% [markdown]
# We now call `get_data()` and store the result as `dm`. To speed up performance, `get_data()` is cached. To clear the cache, call `get_data.clear()`.

# %%
#get_data.clear() # Uncomment this to clear the memoization cache.
dm = get_data()

# %% [markdown]
# # Storing appropriate subject number per datamatrix.

# %%
import re
import os
import numpy as np
from matplotlib import pyplot as plt
from datamatrix import operations as ops
from datamatrix import plot

# Storing appropriate subject number per asc file.
def get_numbers_from_filename(filename):
    return re.search(r'\d+', filename).group(0)


dm.subject_nr = map(
	get_numbers_from_filename,
	dm.path
)

# %% [markdown]
# ## Sanity checks
# Checking length dataframe.
# Checking length different conditions (duration, gestalt).
# Checking combinations start_color, target_color, RSVP_Iteration.
#
# The difference amount of trials of the 125ms duration and can be explained due to the fact that the practice trials consisted of 125ms duration stimuli and letter as gestalt.

# %%
# Checking whether every subjects has the same amount of trials and same amount of practice trials.
# Also checking whether any of the files display an error whereby the target color does not change. 
for (subj_nr,dm_subject) in (ops.split(dm.subject_nr)):
    print("Subj", subj_nr, "Length dm",len(dm_subject))
    print("Subj", subj_nr,"Length practice",len(dm_subject.practice == "True"), "\n")
    for a in range(len(dm_subject)):
        if dm_subject.stream[a] == "['target']" and dm_subject.RSVP_Iteration[a] != 6:
            if dm_subject.target_color[a] == dm_subject.target_color[a+1]:
                print("Registration bug")
                print("Line", a, "Subject", subj_nr)

# Checking length different duration dm´s.              
for (duration,dm_duration) in (ops.split(dm.Duration)):
    print("Duration",duration,"Length",len(dm_duration))
    
# Checking length different gestalt dm´s.
for (gestalt,dm_gestalt) in (ops.split(dm.Gestalt)):
    print("Gestalt",gestalt,"Length",len(dm_gestalt))
    
# Checking length black and white target letters.
for (luminance,dm_luminance) in (ops.split(dm.Duration)):
    print("Duration", luminance, "Length", len(dm_luminance))
    
# Checking length different positions.
even = 0.0
odd = 0.0
for (position_target,dm_position_target) in (ops.split(dm.position_target)):
    
    print("Position target",position_target,len(dm_position_target))
    if position_target % 2 == 0:
        even += len(dm_position_target)
    elif position_target % 2 != 0:
        odd += len(dm_position_target)
print("Length Odd", odd, "Length Even", even)
               
# Checking for possible length differences with regards to combinations of Start_luminance, RSVP_Iteration,start_color, target_color.
# No differences.
for (start_luminance,dm_start_luminance) in (ops.split(dm.Start_luminance)):
    for target_color,dm_target_color in (ops.split(dm_start_luminance.target_color)):
        for (RSVP_Iteration,dm_RSVP_Iteration) in (ops.split(dm_target_color.RSVP_Iteration)):
            for (start_color,dm_start_color) in (ops.split(dm_target_color.RSVP_Iteration)):
                print("Start luminance", start_luminance, "target_color",target_color,"RSVP_Iteration", RSVP_Iteration,"Start color", start_color, "Length DM",len(dm_start_color))
# Out:
# Subj 3 Length dm 366
# Subj 3 Length practice 6
#
# Subj 4 Length dm 366
# Subj 4 Length practice 6
#
# Subj 5 Length dm 366
# Subj 5 Length practice 6
#
# Subj 6 Length dm 366
# Subj 6 Length practice 6
#
# Subj 7 Length dm 366
# Subj 7 Length practice 6
#
# Subj 8 Length dm 366
# Subj 8 Length practice 6
#
# Subj 9 Length dm 366
# Subj 9 Length practice 6
#
# Subj 11 Length dm 366
# Subj 11 Length practice 6
#
# Subj 12 Length dm 366
# Subj 12 Length practice 6
#
# Subj 13 Length dm 366
# Subj 13 Length practice 6
#
# Subj 14 Length dm 366
# Subj 14 Length practice 6
#
# Subj 15 Length dm 366
# Subj 15 Length practice 6
#
# Subj 16 Length dm 366
# Subj 16 Length practice 6
#
# Subj 17 Length dm 366
# Subj 17 Length practice 6
#
# Subj 18 Length dm 366
# Subj 18 Length practice 6
#
# Subj 19 Length dm 366
# Subj 19 Length practice 6
#
# Subj 20 Length dm 366
# Subj 20 Length practice 6
#
# Subj 22 Length dm 366
# Subj 22 Length practice 6
#
# Subj 23 Length dm 366
# Subj 23 Length practice 6
#
# Subj 24 Length dm 366
# Subj 24 Length practice 6
#
# Subj 25 Length dm 366
# Subj 25 Length practice 6
#
# Subj 26 Length dm 366
# Subj 26 Length practice 6
#
# Subj 27 Length dm 366
# Subj 27 Length practice 6
#
# Subj 28 Length dm 366
# Subj 28 Length practice 6
#
# Subj 29 Length dm 366
# Subj 29 Length practice 6
#
# Subj 30 Length dm 366
# Subj 30 Length practice 6
#
# Subj 31 Length dm 366
# Subj 31 Length practice 6
#
# Subj 32 Length dm 366
# Subj 32 Length practice 6
#
# Duration 100 Length 3360
# Duration 125 Length 3528
# Duration 150 Length 3360
# Gestalt background Length 5040
# Gestalt letter Length 5208
# Duration 100 Length 3360
# Duration 125 Length 3528
# Duration 150 Length 3360
# Position target 0 420
# Position target 1 330
# Position target 2 414
# Position target 3 342
# Position target 4 462
# Position target 5 378
# Position target 6 348
# Position target 7 432
# Position target 8 390
# Position target 9 390
# Position target 10 510
# Position target 11 396
# Position target 12 360
# Position target 13 372
# Position target 14 372
# Position target 15 444
# Position target 16 420
# Position target 17 420
# Position target 18 408
# Position target 19 426
# Position target 20 378
# Position target 21 450
# Position target 22 258
# Position target 23 378
# Position target 24 474
# Position target 25 276
# Length Odd 5034.0 Length Even 5214.0
# Start luminance ['black'] target_color black RSVP_Iteration 1 Start color 1 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 1 Start color 2 Length DM 420
# Start luminance ['black'] target_color black RSVP_Iteration 1 Start color 3 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 1 Start color 4 Length DM 420
# Start luminance ['black'] target_color black RSVP_Iteration 1 Start color 5 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 1 Start color 6 Length DM 420
# Start luminance ['black'] target_color black RSVP_Iteration 2 Start color 1 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 2 Start color 2 Length DM 420
# Start luminance ['black'] target_color black RSVP_Iteration 2 Start color 3 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 2 Start color 4 Length DM 420
# Start luminance ['black'] target_color black RSVP_Iteration 2 Start color 5 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 2 Start color 6 Length DM 420
# Start luminance ['black'] target_color black RSVP_Iteration 3 Start color 1 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 3 Start color 2 Length DM 420
# Start luminance ['black'] target_color black RSVP_Iteration 3 Start color 3 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 3 Start color 4 Length DM 420
# Start luminance ['black'] target_color black RSVP_Iteration 3 Start color 5 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 3 Start color 6 Length DM 420
# Start luminance ['black'] target_color black RSVP_Iteration 4 Start color 1 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 4 Start color 2 Length DM 420
# Start luminance ['black'] target_color black RSVP_Iteration 4 Start color 3 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 4 Start color 4 Length DM 420
# Start luminance ['black'] target_color black RSVP_Iteration 4 Start color 5 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 4 Start color 6 Length DM 420
# Start luminance ['black'] target_color black RSVP_Iteration 5 Start color 1 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 5 Start color 2 Length DM 420
# Start luminance ['black'] target_color black RSVP_Iteration 5 Start color 3 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 5 Start color 4 Length DM 420
# Start luminance ['black'] target_color black RSVP_Iteration 5 Start color 5 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 5 Start color 6 Length DM 420
# Start luminance ['black'] target_color black RSVP_Iteration 6 Start color 1 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 6 Start color 2 Length DM 420
# Start luminance ['black'] target_color black RSVP_Iteration 6 Start color 3 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 6 Start color 4 Length DM 420
# Start luminance ['black'] target_color black RSVP_Iteration 6 Start color 5 Length DM 422
# Start luminance ['black'] target_color black RSVP_Iteration 6 Start color 6 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 1 Start color 1 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 1 Start color 2 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 1 Start color 3 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 1 Start color 4 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 1 Start color 5 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 1 Start color 6 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 2 Start color 1 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 2 Start color 2 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 2 Start color 3 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 2 Start color 4 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 2 Start color 5 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 2 Start color 6 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 3 Start color 1 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 3 Start color 2 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 3 Start color 3 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 3 Start color 4 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 3 Start color 5 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 3 Start color 6 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 4 Start color 1 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 4 Start color 2 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 4 Start color 3 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 4 Start color 4 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 4 Start color 5 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 4 Start color 6 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 5 Start color 1 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 5 Start color 2 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 5 Start color 3 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 5 Start color 4 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 5 Start color 5 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 5 Start color 6 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 6 Start color 1 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 6 Start color 2 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 6 Start color 3 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 6 Start color 4 Length DM 420
# Start luminance ['black'] target_color white RSVP_Iteration 6 Start color 5 Length DM 418
# Start luminance ['black'] target_color white RSVP_Iteration 6 Start color 6 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 1 Start color 1 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 1 Start color 2 Length DM 442
# Start luminance ['white'] target_color black RSVP_Iteration 1 Start color 3 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 1 Start color 4 Length DM 442
# Start luminance ['white'] target_color black RSVP_Iteration 1 Start color 5 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 1 Start color 6 Length DM 442
# Start luminance ['white'] target_color black RSVP_Iteration 2 Start color 1 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 2 Start color 2 Length DM 442
# Start luminance ['white'] target_color black RSVP_Iteration 2 Start color 3 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 2 Start color 4 Length DM 442
# Start luminance ['white'] target_color black RSVP_Iteration 2 Start color 5 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 2 Start color 6 Length DM 442
# Start luminance ['white'] target_color black RSVP_Iteration 3 Start color 1 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 3 Start color 2 Length DM 442
# Start luminance ['white'] target_color black RSVP_Iteration 3 Start color 3 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 3 Start color 4 Length DM 442
# Start luminance ['white'] target_color black RSVP_Iteration 3 Start color 5 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 3 Start color 6 Length DM 442
# Start luminance ['white'] target_color black RSVP_Iteration 4 Start color 1 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 4 Start color 2 Length DM 442
# Start luminance ['white'] target_color black RSVP_Iteration 4 Start color 3 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 4 Start color 4 Length DM 442
# Start luminance ['white'] target_color black RSVP_Iteration 4 Start color 5 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 4 Start color 6 Length DM 442
# Start luminance ['white'] target_color black RSVP_Iteration 5 Start color 1 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 5 Start color 2 Length DM 442
# Start luminance ['white'] target_color black RSVP_Iteration 5 Start color 3 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 5 Start color 4 Length DM 442
# Start luminance ['white'] target_color black RSVP_Iteration 5 Start color 5 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 5 Start color 6 Length DM 442
# Start luminance ['white'] target_color black RSVP_Iteration 6 Start color 1 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 6 Start color 2 Length DM 442
# Start luminance ['white'] target_color black RSVP_Iteration 6 Start color 3 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 6 Start color 4 Length DM 442
# Start luminance ['white'] target_color black RSVP_Iteration 6 Start color 5 Length DM 420
# Start luminance ['white'] target_color black RSVP_Iteration 6 Start color 6 Length DM 442
# Start luminance ['white'] target_color white RSVP_Iteration 1 Start color 1 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 1 Start color 2 Length DM 426
# Start luminance ['white'] target_color white RSVP_Iteration 1 Start color 3 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 1 Start color 4 Length DM 426
# Start luminance ['white'] target_color white RSVP_Iteration 1 Start color 5 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 1 Start color 6 Length DM 426
# Start luminance ['white'] target_color white RSVP_Iteration 2 Start color 1 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 2 Start color 2 Length DM 426
# Start luminance ['white'] target_color white RSVP_Iteration 2 Start color 3 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 2 Start color 4 Length DM 426
# Start luminance ['white'] target_color white RSVP_Iteration 2 Start color 5 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 2 Start color 6 Length DM 426
# Start luminance ['white'] target_color white RSVP_Iteration 3 Start color 1 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 3 Start color 2 Length DM 426
# Start luminance ['white'] target_color white RSVP_Iteration 3 Start color 3 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 3 Start color 4 Length DM 426
# Start luminance ['white'] target_color white RSVP_Iteration 3 Start color 5 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 3 Start color 6 Length DM 426
# Start luminance ['white'] target_color white RSVP_Iteration 4 Start color 1 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 4 Start color 2 Length DM 426
# Start luminance ['white'] target_color white RSVP_Iteration 4 Start color 3 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 4 Start color 4 Length DM 426
# Start luminance ['white'] target_color white RSVP_Iteration 4 Start color 5 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 4 Start color 6 Length DM 426
# Start luminance ['white'] target_color white RSVP_Iteration 5 Start color 1 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 5 Start color 2 Length DM 426
# Start luminance ['white'] target_color white RSVP_Iteration 5 Start color 3 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 5 Start color 4 Length DM 426
# Start luminance ['white'] target_color white RSVP_Iteration 5 Start color 5 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 5 Start color 6 Length DM 426
# Start luminance ['white'] target_color white RSVP_Iteration 6 Start color 1 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 6 Start color 2 Length DM 426
# Start luminance ['white'] target_color white RSVP_Iteration 6 Start color 3 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 6 Start color 4 Length DM 426
# Start luminance ['white'] target_color white RSVP_Iteration 6 Start color 5 Length DM 448
# Start luminance ['white'] target_color white RSVP_Iteration 6 Start color 6 Length DM 426

# %% [markdown]
# # Checking performance participants.
# An incorrect trial constitutes a trial where no target was presented plus reports of no target when there was in fact a target. Calculate percentage incorrect/average response time/number of none responses per participant.
# Remove trials in which participants did not report to see the target letter,"no-target" trials and practice trials.

# %%
# Removing practice trials.
print("Before removal practice", len(dm))
dm = dm.practice != "True"
print("After removal practice",len(dm))

incorrect = 0.0
correct = 0.0

# Creating a new column dm.correct, initialised to NA.
dm.correct = "NA"

# Calculating percentage incorrect/avg_response_time/number of None responses per subject.
# An incorrect trial constitutes a trial where no target was presented plus reports of no target when there was in fact a target.

for (subj_nr,dm_subject) in (ops.split(dm.subject_nr)):
    for a in range(5,len(dm_subject.count_trial_sequence),6):
        if (dm_subject.response[a] == "None" and dm_subject.stream[a] == "['target']") or (dm_subject.response[a] == "space" and dm_subject.stream[a] == "['no_target']"):
            dm_subject.correct[a] = "False"  
            incorrect += 1
        else:
            dm_subject.correct[a] = "True"
            correct += 1
            
    # Taking a subset from the space answers in order to compute mean response time when participants answered space.       
    dm_space = dm_subject.response == "space"
    
    # Number of None responses
    # Average reaction time of space responses (If someone has only space responses it is suspicious).
    # Percentage incorrect.
    print("Average response time", round(dm_space.response_time_new_keyboard_response.mean),", subject %s" %  subj_nr )
    print("Number of None responses", len(dm_subject.response == "None" ))
    print("Percentage incorrect %s \n" % round(((incorrect/(correct + incorrect) * 100))))
    
# Removing incorrect trials and removing trials not seen target trials.
for i in range(5,len(dm.count_trial_sequence),6):
    
    # Setting previous trials to None if the response was "Incorrect".
    if (dm.response[i] == "None" and dm.stream[i] == "['target']") or (dm.response[i] == "space" and dm.stream[i] == "['no_target']"):
        dm.correct[i] = "False"
        index = i - 5
        
        while(index <= i):
            dm.correct[index] = "False"
            index += 1
    
    # Setting previous trials to None if the response was "Not seen".
    if dm.response[i] == "None":
        index = i - 5
        
        while(index <= i):
            dm[index].response = "Not seen"
            index += 1
            
print("Before removal incorrect trials N(trials)) = %d" % len(dm))
dm = dm.correct != "False"           
print("After removal incorrect trials N(trials)) = %d" % len(dm))

print("Before removal not seen trials N(trials)) = %d" % len(dm))

dm = dm.response != "Not seen"    
print("After removal not seen N(trials)) = %d" % len(dm))

# Removing no-target trials.
dm = dm.stream == "['target']"
print("N(trials)) = %d" % len(dm))
# Out:
# Before removal practice 10248
# After removal practice 10080
# Average response time 952 , subject 3
# Number of None responses 18
# Percentage incorrect 20
#
# Average response time 858 , subject 4
# Number of None responses 7
# Percentage incorrect 11
#
# Average response time 1185 , subject 5
# Number of None responses 11
# Percentage incorrect 11
#
# Average response time 844 , subject 6
# Number of None responses 6
# Percentage incorrect 8
#
# Average response time 793 , subject 7
# Number of None responses 7
# Percentage incorrect 7
#
# Average response time 1196 , subject 8
# Number of None responses 21
# Percentage incorrect 12
#
# Average response time 1115 , subject 9
# Number of None responses 11
# Percentage incorrect 12
#
# Average response time 1505 , subject 11
# Number of None responses 15
# Percentage incorrect 12
#
# Average response time 1442 , subject 12
# Number of None responses 18
# Percentage incorrect 13
#
# Average response time 1012 , subject 13
# Number of None responses 9
# Percentage incorrect 13
#
# Average response time 992 , subject 14
# Number of None responses 8
# Percentage incorrect 12
#
# Average response time 905 , subject 15
# Number of None responses 7
# Percentage incorrect 12
#
# Average response time 832 , subject 16
# Number of None responses 7
# Percentage incorrect 11
#
# Average response time 916 , subject 17
# Number of None responses 7
# Percentage incorrect 10
#
# Average response time 855 , subject 18
# Number of None responses 6
# Percentage incorrect 10
#
# Average response time 1404 , subject 19
# Number of None responses 13
# Percentage incorrect 10
#
# Average response time 1522 , subject 20
# Number of None responses 32
# Percentage incorrect 12
#
# Average response time 654 , subject 22
# Number of None responses 5
# Percentage incorrect 12
#
# Average response time 1625 , subject 23
# Number of None responses 20
# Percentage incorrect 13
#
# Average response time 1118 , subject 24
# Number of None responses 8
# Percentage incorrect 13
#
# Average response time 1061 , subject 25
# Number of None responses 8
# Percentage incorrect 12
#
# Average response time 1372 , subject 26
# Number of None responses 18
# Percentage incorrect 13
#
# Average response time 1276 , subject 27
# Number of None responses 12
# Percentage incorrect 13
#
# Average response time 1101 , subject 28
# Number of None responses 10
# Percentage incorrect 13
#
# Average response time 988 , subject 29
# Number of None responses 11
# Percentage incorrect 13
#
# Average response time 1045 , subject 30
# Number of None responses 7
# Percentage incorrect 13
#
# Average response time 1010 , subject 31
# Number of None responses 10
# Percentage incorrect 13
#
# Average response time 1419 , subject 32
# Number of None responses 9
# Percentage incorrect 13
#
# Before removal incorrect trials N(trials)) = 10080
# After removal incorrect trials N(trials)) = 8814
# Before removal not seen trials N(trials)) = 8814
# After removal not seen N(trials)) = 7980
# N(trials)) = 7980

# %% [markdown]
# ## Baseline correction

# %%
# Baseline correction
from matplotlib import pyplot as plt
from datamatrix import series as srs

dm.pupil_baseline = srs.reduce_(srs.window(dm.pupil,0,10))

plt.hist(dm.pupil_baseline, bins = 100, range=(0,5000))
plt.show()
# Out:
# /home/ko/anaconda3/lib/python3.6/site-packages/datamatrix/series.py:377: RuntimeWarning: Mean of empty slice
#   a = operation(series, axis=1)
# /home/ko/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:747: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= mn)
# /home/ko/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:748: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= mx)

# %%
# Trimming data
print("Before trimming: %d" %len(dm))
dm = (dm.pupil_baseline > 600) & (dm.pupil_baseline < 2000)
print("After trimming: %d" %len(dm))
# Out:
# Before trimming: 7980
# /home/ko/anaconda3/lib/python3.6/site-packages/datamatrix/_datamatrix/_numericcolumn.py:158: RuntimeWarning: invalid value encountered in greater
#   b = op(self._seq, _other)
# /home/ko/anaconda3/lib/python3.6/site-packages/datamatrix/_datamatrix/_numericcolumn.py:158: RuntimeWarning: invalid value encountered in less
#   b = op(self._seq, _other)
# After trimming: 7681

# %% [markdown]
# # Plot mean pupil trace across target color
#
# Plotting pupil size for trials in which the target was white and trials in which the target was black across six different conditions across the duration of stream.

# %%
plot.new(size=(50,20))
plt.suptitle("Average pupil size across target color", fontsize = 50)
i = 0

for (duration,dm_Duration) in (ops.split(dm.Duration)):
    for gestalt,dm_gestalt in ops.split(dm_Duration.Gestalt):
        Axes = plt.subplot(2,3,i+1)
        duration_range = (duration * 26 + 500)/10
        Axes.set_xlim(0,duration_range)
        Axes.set_ylim(1100,1400)
        plt.title("%s ms, %s gestalt" % (duration,gestalt), fontsize=30)
        i += 1
        colors = ["orange","blue"]
        for luminance, dm_luminance in ops.split(dm_gestalt.target_color):
            plot.trace(
                dm_luminance.pupil,
                label=luminance,
                color=colors.pop()   
            )
            
        # Adjusting legend properties
        leg = Axes.legend(fontsize = 25)
        leg.set_title("Target color", prop = {'size':25})
        
        # Setting linewidth
        for legobj in leg.legendHandles:
            legobj.set_linewidth(10)

        
        plt.ylabel("Mean pupil area",fontsize=35)
        plt.xlabel("Time (ms)",fontsize=35)
        locs, labels = plt.xticks()
        x_label = [int(x*10) for x in locs]
        plt.xticks(locs,x_label)
        Axes.xaxis.set_tick_params(labelsize=24)
        Axes.yaxis.set_tick_params(labelsize=24)
plt.savefig('Average_ps_stream.png')
plt.show()
# Out:
# /home/ko/anaconda3/lib/python3.6/site-packages/datamatrix/_datamatrix/_seriescolumn.py:124: RuntimeWarning: Mean of empty slice
#   return nanmean(self._seq, axis=0)
# /home/ko/anaconda3/lib/python3.6/site-packages/numpy/lib/nanfunctions.py:1423: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)

# %% [markdown]
# ## Plotting mean pupil size across of start color
# The start color refers to the color of the first stimulus.

# %%
plot.new(size=(50,20))
plt.suptitle("Average pupil size across start color", fontsize = 50)
i = 0

for (duration,dm_Duration) in (ops.split(dm.Duration)):
    for gestalt,dm_gestalt in ops.split(dm_Duration.Gestalt):
        Axes = plt.subplot(2,3,i+1) 
        duration_range = (duration * 26 + 500)/10
        Axes.set_xlim(0,duration_range)
        Axes.set_ylim(1000,1400)

        plt.title("%s ms, %s gestalt" % (duration,gestalt), fontsize=30)
        i += 1
        colors = ["orange","blue"]
        for luminance, dm_luminance in ops.split(dm_gestalt.start_color):
            plot.trace(
                dm_luminance.pupil,
                label=luminance,
                color=colors.pop()   
            )
            
        # Adjusting legend properties
        leg = Axes.legend(fontsize = 25)
        leg.set_title("Start color", prop = {'size':25})
        
        # Setting linewidth
        for legobj in leg.legendHandles:
            legobj.set_linewidth(10)
        
        plt.ylabel("Mean pupil area (mm)",fontsize=35)
        plt.xlabel("Time (ms)",fontsize=35)
        locs, labels = plt.xticks()
        
        # Converting samples to ms
        x_label = [int(x*10) for x in locs]
        plt.xticks(locs,x_label)
        Axes.xaxis.set_tick_params(labelsize=24)
        Axes.yaxis.set_tick_params(labelsize=24)
plt.savefig('Average_ps_stream(start_color).png')
plt.show()
# Out:
# /home/ko/anaconda3/lib/python3.6/site-packages/datamatrix/_datamatrix/_seriescolumn.py:124: RuntimeWarning: Mean of empty slice
#   return nanmean(self._seq, axis=0)
# /home/ko/anaconda3/lib/python3.6/site-packages/numpy/lib/nanfunctions.py:1423: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)

# %% [markdown]
# ## Inspect individual participants per condition
# A line above the X-axis suggests an effect. Vice versa, a line below the X-axis suggests an opposite effect. A line around the X-axis suggests no effect.

# %%
plot.new(size=(50,20))
plt.suptitle("Dark average pupil size subtracted by white average pupil size", fontsize = 50)



def plot_subject_trace(dm, subject_nr,duration): 
    dmlight, dmdark =  ops.split(dm.target_color,"white","black")
    y = dmdark.pupil.mean - dmlight.pupil.mean
    plt.plot(y, color = "green", label = (subj_nr + 1))
    plt.xlim([0,((duration * 28 + 500)/10)])
    plt.ylabel("Difference pupil size \n dark/white target",fontsize=35)
    plt.xlabel("Time (ms)",fontsize=35)
    locs, labels = plt.xticks()
    # Converting samples to ms
    x_label = [int(x*10) for x in locs]
    plt.xticks(locs,x_label) 

    
i = 0
for (duration,dm_Duration) in (ops.split(dm.Duration)):
    for gestalt,dm_gestalt in ops.split(dm_Duration.Gestalt):
        Axes = plt.subplot(2,3,i+1)
        i += 1
        for subj_nr, dm_subject in ops.split(dm_gestalt.subject_nr):
            plot_subject_trace(dm_subject, subj_nr,duration)
            plt.axhline(0, color = "black", linestyle = ":")
        plt.title("%s ms, %s gestalt" % (duration,gestalt), fontsize=30)

plt.show()
# Out:
# /home/ko/anaconda3/lib/python3.6/site-packages/datamatrix/_datamatrix/_seriescolumn.py:124: RuntimeWarning: Mean of empty slice
#   return nanmean(self._seq, axis=0)

# %% [markdown]
# # Curve fitting the sinus wave
# Finding out whether pupil oscillations across different start color are in anti-phase.

# %%
from scipy.optimize import curve_fit
from scipy.signal import find_peaks_cwt
import math 
import os

# Function that will be fitted
def fit_func(x,a,phase,offset):
    return offset + a*np.sin((2 *np.pi*((1/33.332)*x)+phase))

# Subsetting DM to dm with 150ms duration and background gestalt across start_color.
dm_150 = dm.Duration == 150 
dm_150_background = dm_150.Gestalt == "background"

colors = ["orange","blue"]
for luminance, dm_luminance in ops.split(dm_150_background.start_color):                
    dm_luminance.pupil = srs.window(dm_luminance.pupil, start = 60, end = 460)
    
   
    plot.trace(
        dm_luminance.pupil,
        label=luminance,
        color=colors.pop()   
    )

    xdata = np.arange(start = 0, stop = len(dm_luminance.pupil[0][:]),step =1)
    ydata = dm_luminance.pupil.mean
    
    axes = plt.gca()
    box = axes.get_position()
    axes.set_position([box.x0, box.y0, box.width * 0.8, box.height])

    # Fitting curve.
    popt, pcov = curve_fit(fit_func, xdata, ydata, bounds = ([0,0,-np.inf],[np.inf,2*np.pi,np.inf]))
    
    plt.plot(xdata, fit_func(xdata, *popt), 'g--', label='Fit:\nPhase=%5.3f π' % (popt[1]/math.pi))
    plt.xlabel("Time (ms)",fontsize=24)
    plt.ylabel("Mean pupil area (mm)",fontsize=24)

    # Converting samples to ms
    x_label = [(int(x*10)+600) for x in locs]
    plt.xticks(locs,x_label)
    axes.set_xlim([0,420])
    axes.set_ylim([1000,1300])
    
    # Put a legend to the right of the current axis
    axes.set_position([box.x0, box.y0, box.width * 0.8, box.height])
    leg = axes.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=3, prop={'size': 10})
    leg.set_title("Start color and Fit", prop = {'size':15})
    
    # Setting linewidth
    for legobj in leg.legendHandles:
        legobj.set_linewidth(10)
    
    plt.savefig('Sinus_fit_%s.png' % luminance,bbox_inches='tight')
    plt.show()

# %% [markdown]
# # Statistics
# Testing whether phases extracted from fitting individual pupil traces across different start color significantly differ.

# %%
from datamatrix import DataMatrix, SeriesColumn,convert
from scipy.stats import mannwhitneyu, stats

# Subsetting DM to DM with 150ms duration and background gestalt across start_color.
dm_150 = dm.Duration == 150 
dm_150_background = dm_150.Gestalt == "background"

# Initialising phase and phase_diff series columns.
dm_150_background.phase = float("nan")
dm_150_background.phase_diff = float("nan")

# Interpolating due to inability of curve_fit to handle nans.
dm_150_background.pupil = srs.interpolate(dm_150_background.pupil)

# Truncating first 60 samples which display no (clear) oscillation.
dm_150_background.pupil = srs.window(dm_150_background.pupil, start = 60, end = 460)

for a in range(len(dm_150_background)):

    xdata = np.arange(start = 0, stop = len(dm_150_background.pupil[:][a]),step =1)
    ydata = dm_150_background.pupil[a][:]

    # Ignoring Runtime errors.
    try:
        popt, pcov = curve_fit(fit_func, xdata,ydata,bounds = ([0,0,0],[np.inf,2*np.pi,2000]))
    except RuntimeError:
        print('A Runtime error occurred: %s' % a)
        pass 
    dm_150_background[a].phase = popt[1]
    dm_150_background.phase_diff[a]= abs(np.pi -  dm_150_background[a].phase)
    

## Checking assumptions Mannwhitneyu
# Checking for normality (data is not normally distributed)
print(stats.normaltest(dm_150_background.phase))

# Splitting dm_150_background to do a t-test.
dm_150_background_white = dm_150_background.start_color == "white"
dm_150_background_black = dm_150_background.start_color == "black"

# Checking distributions data.
plt.hist(dm_150_background_white.phase_diff,bins = 30, range=(0,2*np.pi),label = "Black", color = "blue") 
plt.hist(dm_150_background_black.phase_diff,bins = 30, range=(0,2*np.pi),label = "White",color = "orange")
plt.legend()
plt.show()

# Mannwhitneyu.
mannwhitneyu(dm_150_background_white.phase_diff,dm_150_background_black.phase_diff,alternative = "greater")
# Out:
# A Runtime error occurred: 220
# A Runtime error occurred: 234
# A Runtime error occurred: 238
# A Runtime error occurred: 241
# A Runtime error occurred: 248
# A Runtime error occurred: 252
# A Runtime error occurred: 253
# A Runtime error occurred: 415
# A Runtime error occurred: 612
# A Runtime error occurred: 624
# A Runtime error occurred: 969
# NormaltestResult(statistic=462.11330398405505, pvalue=4.5016428159753441e-101)
# MannwhitneyuResult(statistic=330717.5, pvalue=7.1094324536269806e-97)

# %% [markdown]
# # Circular histogram.
# A visual representation of how phases extracted from each individual pupil trace are distributed.

# %%
from matplotlib.pyplot import figure, show, grid
import matplotlib.ticker as tck

def pi_convert(x):
    x = x/np.pi
    if x == 2 *np.pi or x == 0:
        return r"0 / $2\pi$"
    return r"${} \pi$".format(x)

# Convert to np.array for circular hist.
dm_150_background_white.phase = np.asarray(dm_150_background_white.phase)
dm_150_background_black.phase = np.asarray(dm_150_background_black.phase)

fig = figure(figsize=(10, 10))

colors = ["orange","blue"]
plot_labels = ["white","black"]

for phase in [dm_150_background_white.phase,dm_150_background_black.phase]:
    N = len(phase)
    
    theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
    radii = phase
    
    # Plotting
    ax = fig.add_subplot(111, polar=True,axisbg='#d5de9c')
    
    ax.hist(phase,bins = 100, color = colors.pop(),label = plot_labels.pop())
    ax.set_rlabel_position(60)

    # Converting samples to ms
    locs, labels = plt.xticks()
    x_label = [pi_convert(x) for x in locs]
    plt.xticks(locs,x_label,fontsize=24,weight= "heavy")
    plt.yticks(fontsize=20,weight= "heavy")
    
# Adjusting legend properties
leg = ax.legend(loc='upper left', bbox_to_anchor=(1.25, 0.5),prop={'size': 15})
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
leg.set_title("Start color", prop = {'size':25})

# Setting linewidth
for legobj in leg.legendHandles:
    legobj.set_linewidth(10)
    
plt.savefig('Circular_histogram.png',bbox_inches='tight')
plt.show()
# Out:
# /home/ko/anaconda3/lib/python3.6/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
